# %%
import eli5
from eli5.lime import TextExplainer
from os.path import join, dirname, realpath

from load_data import load_dataset

from model import predict_proba
__file__ = realpath('__file__')
data_file = join(dirname(dirname(dirname(__file__))), "data", "fb_bank_category",
                 "corpus", "test.xlsx")
X_test, y_test = load_dataset(data_file)
doc = X_test[0]

te = TextExplainer(random_state=42)
te.fit(X_test[0], predict_proba)

print(0)
# Out:
# 0

# %%
X_test[:5]
# Out:
# ['Chào bạn Hùng Nguyễn Thanh, hiện tại một số chi nhánh BIDV đang thu bù phí dịch vụ BSMS của những khách hàng trước đó có đăng ký nhưng chưa thu được. Do vấn đề bảo mật, Anh Cố Vấn chưa kiểm tra được tình trạng dịch vụ qua Mạng xã hội, bạn vui lòng liên hệ HotLine BIDV theo số 19009247 / 024.22200588 hoặc gửi email tới địa chỉ bidv247@bidv.com.vn để kiểm tra và xử lý nhé. Cảm ơn bạn!',
#  'Hotline khó gọi quá gọi mãi ko thưa máy à',
#  'Bạn Hùng Nguyễn Thanh thân mến, nếu chưa liên hệ Hotline BIDV được, bạn vui lòng gửi email kèm thông tin cá nhân, vấn đề cần xử lý vào hòm thư bidv247@bidv.com.vn để được xử lý nhé. Cảm ơn bạn!',
#  'Chữ ký số và số hóa tài liệu .bao giờ cơ quan mình làm dc cái này',
#  'Chào bạn Nguyễn Hương. Anh Cố Vấn có thể hỗ trợ thông tin gì cho bạn không?']

# %%
y_test[:5]
# Out:
# [['INTERNET BANKING', 'INTEREST RATE'],
#  ['CUSTOMER SUPPORT'],
#  ['CUSTOMER SUPPORT'],
#  ['CUSTOMER SUPPORT'],
#  ['CUSTOMER SUPPORT']]

# %%
import joblib
y_transform = joblib.load(join(dirname(__file__), "model", "label.transformer.bin"))

# %%
list(y_transform.classes_)
# Out:
# ['ACCOUNT',
#  'CARD',
#  'CREDIT',
#  'CUSTOMER SUPPORT',
#  'DISCOUNT',
#  'INTEREST RATE',
#  'INTERNET BANKING',
#  'LOAN',
#  'MONEY TRANSFER',
#  'OTHER',
#  'PAYMENT',
#  'PROMOTION',
#  'SAVING',
#  'SECURITY',
#  'TRADEMARK']

# %%
doc = "Muon lam the tin dung thi the nao"
te.fit(doc, predict_proba)
te.show_prediction(target_names=list(y_transform.classes_))
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=ACCOUNT
#
# </b>
#
#
#     (probability <b>0.015</b>, score <b>-4.303</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
# ...
